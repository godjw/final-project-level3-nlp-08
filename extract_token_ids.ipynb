# %%
import json

# %%
with open("/opt/ml/outputs/checkpoint-189/tokenizer.json", "r", encoding="utf8") as f:
    file = json.load(f)
file.keys()
# Out:
# dict_keys(['version', 'truncation', 'padding', 'added_tokens', 'normalizer', 'pre_tokenizer', 'post_processor', 'decoder', 'model'])

# %%
tkn2idx = file["model"]["vocab"]
idx2tkn = {val: key for key, val in tkn2idx.items()}

# %%
tkn2idx
# Out:
# {'<s>': 0,
#  '</s>': 1,
#  '<usr>': 2,
#  '<pad>': 3,
#  '<sys>': 4,
#  '<unk>': 5,
#  '<mask>': 6,
#  '<d>': 7,
#  '</d>': 8,
#  '<unused0>': 9,
#  '<unused1>': 10,
#  '<unused2>': 11,
#  '<unused3>': 12,
#  '<unused4>': 13,
#  '<unused5>': 14,
#  '<unused6>': 15,
#  '<unused7>': 16,
#  '<unused8>': 17,
#  '<unused9>': 18,
#  '<unused10>': 19,
#  '<unused11>': 20,
#  '<unused12>': 21,
#  '<unused13>': 22,
#  '<unused14>': 23,
#  '<unused15>': 24,
#  '<unused16>': 25,
#  '<unused17>': 26,
#  '<unused18>': 27,
#  '<unused19>': 28,
#  '<unused20>': 29,
#  '<unused21>': 30,
#  '<unused22>': 31,
#  '<unused23>': 32,
#  '<unused24>': 33,
#  '<unused25>': 34,
#  '<unused26>': 35,
#  '<unused27>': 36,
#  '<unused28>': 37,
#  '<unused29>': 38,
#  '<unused30>': 39,
#  '<unused31>': 40,
#  '<unused32>': 41,
#  '<unused33>': 42,
#  '<unused34>': 43,
#  '<unused35>': 44,
#  '<unused36>': 45,
#  '<unused37>': 46,
#  '<unused38>': 47,
#  '<unused39>': 48,
#  '<unused40>': 49,
#  '<unused41>': 50,
#  '<unused42>': 51,
#  '<unused43>': 52,
#  '<unused44>': 53,
#  '<unused45>': 54,
#  '<unused46>': 55,
#  '<unused47>': 56,
#  '<unused48>': 57,
#  '<unused49>': 58,
#  '<unused50>': 59,
#  '<unused51>': 60,
#  '<unused52>': 61,
#  '<unused53>': 62,
#  '<unused54>': 63,
#  '<unused55>': 64,
#  '<unused56>': 65,
#  '<unused57>': 66,
#  '<unused58>': 67,
#  '<unused59>': 68,
#  '<unused60>': 69,
#  '<unused61>': 70,
#  '<unused62>': 71,
#  '<unused63>': 72,
#  '<unused64>': 73,
#  '<unused65>': 74,
#  '<unused66>': 75,
#  '<unused67>': 76,
#  '<unused68>': 77,
#  '<unused69>': 78,
#  '<unused70>': 79,
#  '<unused71>': 80,
#  '<unused72>': 81,
#  '<unused73>': 82,
#  '<unused74>': 83,
#  '<unused75>': 84,
#  '<unused76>': 85,
#  '<unused77>': 86,
#  '<unused78>': 87,
#  '<unused79>': 88,
#  '<unused80>': 89,
#  '<unused81>': 90,
#  '<unused82>': 91,
#  '<unused83>': 92,
#  '<unused84>': 93,
#  '<unused85>': 94,
#  '<unused86>': 95,
#  '<unused87>': 96,
#  '<unused88>': 97,
#  '<unused89>': 98,
#  '<unused90>': 99,
#  '<unused91>': 100,
#  '<unused92>': 101,
#  '<unused93>': 102,
#  '<unused94>': 103,
#  '<unused95>': 104,
#  '<unused96>': 105,
#  '<unused97>': 106,
#  '<unused98>': 107,
#  '<unused99>': 108,
#  ':-)': 109,
#  ':)': 110,
#  '-)': 111,
#  '(-:': 112,
#  '(:-)': 113,
#  '(:-(': 114,
#  '-}': 115,
#  '8-O': 116,
#  "'-)": 117,
#  ':-#': 118,
#  ':-*': 119,
#  ':-/': 120,
#  ':->': 121,
#  ':-@': 122,
#  ':-d': 123,
#  ':-V': 124,
#  ':-X': 125,
#  ':-\\': 126,
#  ':-]': 127,
#  ';-(': 128,
#  '>;->': 129,
#  ';^)': 130,
#  '%-)': 131,
#  '):-(': 132,
#  '3:]': 133,
#  ':-&': 134,
#  '8:-)': 135,
#  ':-)8<': 136,
#  ':-O': 137,
#  ':-6': 138,
#  '+:-)': 139,
#  'O:-)': 140,
#  ':-<': 141,
#  ':-?': 142,
#  ':-E': 143,
#  ':-Q': 144,
#  ':-}X': 145,
#  ':-[': 146,
#  ':-a': 147,
#  ':-{': 148,
#  ':-{}': 149,
#  ':^)': 150,
#  '<:-l': 151,
#  ':=)': 152,
#  '>:->': 153,
#  '>:-l': 154,
#  '@:-)': 155,
#  '@:-}': 156,
#  'C=:-)': 157,
#  'X:-)': 158,
#  '[:-)': 159,
#  '[:]': 160,
#  '{:-)': 161,
#  'l^o': 162,
#  '}:^#)': 163,
#  ':-(=)': 164,
#  'O-)': 165,
#  ':-3': 166,
#  ':=': 167,
#  ':-"': 168,
#  'P-(': 169,
#  '?-(': 170,
#  'd:-)': 171,
#  ':8)': 172,
#  ':-7': 173,
#  '):-)': 174,
#  ':/\\)': 175,
#  '8(:-)': 176,
#  '([(': 177,
#  ':-(*)': 178,
#  '&-l': 179,
#  ':-e': 180,
#  ':(': 181,
#  ':,(': 182,
#  ':-(': 183,
#  ':-P': 184,
#  ':-S': 185,
#  ':-C': 186,
#  ':-r': 187,
#  ':-t': 188,
#  ':-W': 189,
#  'X-(': 190,
#  'l-O': 191,
#  'l:-O': 192,
#  '$-)': 193,
#  ':-!': 194,
#  ':----}': 195,
#  '=:-)': 196,
#  '=:-(': 197,
#  '3:[': 198,
#  '8<:-)': 199,
#  ':#)': 200,
#  '8-#': 201,
#  'B-)': 202,
#  '8-)': 203,
#  '|-(': 204,
#  'H-)': 205,
#  ']-I': 206,
#  'V^J': 207,
#  '+-(': 208,
#  '~:-P': 209,
#  "`'": 210,
#  'L-P': 211,
#  'BI': 212,
#  'O|': 213,
#  '^^': 214,
#  'ㅜㅜ': 215,
#  'ㅠㅠ': 216,
#  'ㅡㅡ': 217,
#  '😠': 218,
#  '👿': 219,
#  '😧': 220,
#  '😰': 221,
#  '😲': 222,
#  '😁': 223,
#  '🐻': 224,
#  '🐱': 225,
#  '😹': 226,
#  '😼': 227,
#  '🤡': 228,
#  '🥶': 229,
#  '😖': 230,
#  '😕': 231,
#  '🐮': 232,
#  '🤠': 233,
#  '😿': 234,
#  '😢': 235,
#  '😞': 236,
#  '😵': 237,
#  '🐶': 238,
#  '😓': 239,
#  '🐲': 240,
#  '🤤': 241,
#  '😑': 242,
#  '😘': 243,
#  '😋': 244,
#  '😱': 245,
#  '🤮': 246,
#  '🤭': 247,
#  '🤕': 248,
#  '😷': 249,
#  '🧐': 250,
#  '😮': 251,
#  '🤨': 252,
#  '🙄': 253,
#  '😤': 254,
#  '🤬': 255,
#  '😂': 256,
#  '🤒': 257,
#  '😛': 258,
#  '😶': 259,
#  '😨': 260,
#  '🌛': 261,
#  '😳': 262,
#  '🦊': 263,
#  '🐸': 264,
#  '☹': 265,
#  '☹️': 266,
#  '😦': 267,
#  '🌝': 268,
#  '😬': 269,
#  '😺': 270,
#  '😸': 271,
#  '😀': 272,
#  '😃': 273,
#  '😄': 274,
#  '😅': 275,
#  '😆': 276,
#  '🐹': 277,
#  '🐴': 278,
#  '🥵': 279,
#  '🤗': 280,
#  '😯': 281,
#  '😽': 282,
#  '😗': 283,
#  '😚': 284,
#  '😙': 285,
#  '🌜': 286,
#  '🦁': 287,
#  '😭': 288,
#  '🤥': 289,
#  '🤦🏿\u200d♂': 290,
#  '🤦🏻\u200d♂': 291,
#  '🤦🏾\u200d♂': 292,
#  '🤦🏼\u200d♂': 293,
#  '🤦🏽\u200d♂': 294,
#  '🤦\u200d♂': 295,
#  '🤦🏿\u200d♂️': 296,
#  '🤦🏻\u200d♂️': 297,
#  '🤦🏾\u200d♂️': 298,
#  '🤦🏼\u200d♂️': 299,
#  '🤦🏽\u200d♂️': 300,
#  '🤦\u200d♂️': 301,
#  '🤑': 302,
#  '🐵': 303,
#  '🐭': 304,
#  '🤢': 305,
#  '🤓': 306,
#  '😐': 307,
#  '🌚': 308,
#  '🐼': 309,
#  '🥳': 310,
#  '😔': 311,
#  '😣': 312,
#  '🤦': 313,
#  '🤦🏿': 314,
#  '🤦🏻': 315,
#  '🤦🏾': 316,
#  '🤦🏼': 317,
#  '🤦🏽': 318,
#  '🐷': 319,
#  '🥺': 320,
#  '😾': 321,
#  '😡': 322,
#  '🐰': 323,
#  '😌': 324,
#  '🤖': 325,
#  '😥': 326,
#  '🤫': 327,
#  '😴': 328,
#  '😪': 329,
#  '🙁': 330,
#  '🙂': 331,
#  '😻': 332,
#  '☺': 333,
#  '☺️': 334,
#  '🥰': 335,
#  '😇': 336,
#  '😍': 337,
#  '😈': 338,
#  '😊': 339,
#  '😎': 340,
#  '😏': 341,
#  '🤧': 342,
#  '😝': 343,
#  '🌞': 344,
#  '🤔': 345,
#  '🐯': 346,
#  '😫': 347,
#  '😒': 348,
#  '🦄': 349,
#  '🙃': 350,
#  '🙀': 351,
#  '😩': 352,
#  '🌬': 353,
#  '🌬️': 354,
#  '😉': 355,
#  '😜': 356,
#  '🐺': 357,
#  '🤦🏿\u200d♀': 358,
#  '🤦🏻\u200d♀': 359,
#  '🤦🏾\u200d♀': 360,
#  '🤦🏼\u200d♀': 361,
#  '🤦🏽\u200d♀': 362,
#  '🤦\u200d♀': 363,
#  '🤦🏿\u200d♀️': 364,
#  '🤦🏻\u200d♀️': 365,
#  '🤦🏾\u200d♀️': 366,
#  '🤦🏼\u200d♀️': 367,
#  '🤦🏽\u200d♀️': 368,
#  '🤦\u200d♀️': 369,
#  '🥴': 370,
#  '😟': 371,
#  '🥱': 372,
#  '🤪': 373,
#  '🤐': 374,
#  '\t': 375,
#  '\n': 376,
#  '!': 377,
#  '"': 378,
#  '#': 379,
#  '$': 380,
#  '%': 381,
#  '&': 382,
#  "'": 383,
#  '(': 384,
#  ')': 385,
#  '*': 386,
#  '+': 387,
#  ',': 388,
#  '-': 389,
#  '.': 390,
#  '/': 391,
#  '0': 392,
#  '1': 393,
#  '2': 394,
#  '3': 395,
#  '4': 396,
#  '5': 397,
#  '6': 398,
#  '7': 399,
#  '8': 400,
#  '9': 401,
#  ':': 402,
#  ';': 403,
#  '<': 404,
#  '=': 405,
#  '>': 406,
#  '?': 407,
#  '@': 408,
#  'A': 409,
#  'B': 410,
#  'C': 411,
#  'D': 412,
#  'E': 413,
#  'F': 414,
#  'G': 415,
#  'H': 416,
#  'I': 417,
#  'J': 418,
#  'K': 419,
#  'L': 420,
#  'M': 421,
#  'N': 422,
#  'O': 423,
#  'P': 424,
#  'Q': 425,
#  'R': 426,
#  'S': 427,
#  'T': 428,
#  'U': 429,
#  'V': 430,
#  'W': 431,
#  'X': 432,
#  'Y': 433,
#  'Z': 434,
#  '[': 435,
#  '\\': 436,
#  ']': 437,
#  '^': 438,
#  '_': 439,
#  '`': 440,
#  'a': 441,
#  'b': 442,
#  'c': 443,
#  'd': 444,
#  'e': 445,
#  'f': 446,
#  'g': 447,
#  'h': 448,
#  'i': 449,
#  'j': 450,
#  'k': 451,
#  'l': 452,
#  'm': 453,
#  'n': 454,
#  'o': 455,
#  'p': 456,
#  'q': 457,
#  'r': 458,
#  's': 459,
#  't': 460,
#  'u': 461,
#  'v': 462,
#  'w': 463,
#  'x': 464,
#  'y': 465,
#  'z': 466,
#  '{': 467,
#  '|': 468,
#  '}': 469,
#  '~': 470,
#  'ᄀ': 471,
#  'ᄁ': 472,
#  'ᄂ': 473,
#  'ᄃ': 474,
#  'ᄄ': 475,
#  'ᄅ': 476,
#  'ᄆ': 477,
#  'ᄇ': 478,
#  'ᄈ': 479,
#  'ᄉ': 480,
#  'ᄊ': 481,
#  'ᄋ': 482,
#  'ᄌ': 483,
#  'ᄍ': 484,
#  'ᄎ': 485,
#  'ᄏ': 486,
#  'ᄐ': 487,
#  'ᄑ': 488,
#  'ᄒ': 489,
#  'ᄔ': 490,
#  'ᄕ': 491,
#  'ᄚ': 492,
#  'ᄜ': 493,
#  'ᄝ': 494,
#  'ᄞ': 495,
#  'ᄠ': 496,
#  'ᄡ': 497,
#  'ᄢ': 498,
#  'ᄣ': 499,
#  'ᄧ': 500,
#  'ᄩ': 501,
#  'ᄫ': 502,
#  'ᄬ': 503,
#  'ᄭ': 504,
#  'ᄮ': 505,
#  'ᄯ': 506,
#  'ᄲ': 507,
#  'ᄶ': 508,
#  'ᅀ': 509,
#  'ᅇ': 510,
#  'ᅌ': 511,
#  'ᅗ': 512,
#  'ᅘ': 513,
#  'ᅙ': 514,
#  'ᅠ': 515,
#  'ᅡ': 516,
#  'ᅢ': 517,
#  'ᅣ': 518,
#  'ᅤ': 519,
#  'ᅥ': 520,
#  'ᅦ': 521,
#  'ᅧ': 522,
#  'ᅨ': 523,
#  'ᅩ': 524,
#  'ᅪ': 525,
#  'ᅫ': 526,
#  'ᅬ': 527,
#  'ᅭ': 528,
#  'ᅮ': 529,
#  'ᅯ': 530,
#  'ᅰ': 531,
#  'ᅱ': 532,
#  'ᅲ': 533,
#  'ᅳ': 534,
#  'ᅴ': 535,
#  'ᅵ': 536,
#  'ᆄ': 537,
#  'ᆅ': 538,
#  'ᆈ': 539,
#  'ᆑ': 540,
#  'ᆒ': 541,
#  'ᆔ': 542,
#  'ᆞ': 543,
#  'ᆡ': 544,
#  'ᆪ': 545,
#  'ᆬ': 546,
#  'ᆭ': 547,
#  'ᆰ': 548,
#  'ᆱ': 549,
#  'ᆲ': 550,
#  'ᆳ': 551,
#  'ᆴ': 552,
#  'ᆵ': 553,
#  'ᇇ': 554,
#  'ᇈ': 555,
#  'ᇌ': 556,
#  'ᇎ': 557,
#  'ᇓ': 558,
#  'ᇗ': 559,
#  'ᇙ': 560,
#  'ᇝ': 561,
#  'ᇟ': 562,
#  'ᇱ': 563,
#  'ᇲ': 564,
#  '▁': 565,
#  'ぁ': 566,
#  'あ': 567,
#  'ぃ': 568,
#  'い': 569,
#  'ぅ': 570,
#  'う': 571,
#  'ぇ': 572,
#  'え': 573,
#  'ぉ': 574,
#  'お': 575,
#  'か': 576,
#  'が': 577,
#  'き': 578,
#  'ぎ': 579,
#  'く': 580,
#  'ぐ': 581,
#  'け': 582,
#  'げ': 583,
#  'こ': 584,
#  'ご': 585,
#  'さ': 586,
#  'ざ': 587,
#  'し': 588,
#  'じ': 589,
#  'す': 590,
#  'ず': 591,
#  'せ': 592,
#  'ぜ': 593,
#  'そ': 594,
#  'ぞ': 595,
#  'た': 596,
#  'だ': 597,
#  'ち': 598,
#  'ぢ': 599,
#  'っ': 600,
#  'つ': 601,
#  'づ': 602,
#  'て': 603,
#  'で': 604,
#  'と': 605,
#  'ど': 606,
#  'な': 607,
#  'に': 608,
#  'ぬ': 609,
#  'ね': 610,
#  'の': 611,
#  'は': 612,
#  'ば': 613,
#  'ぱ': 614,
#  'ひ': 615,
#  'び': 616,
#  'ぴ': 617,
#  'ふ': 618,
#  'ぶ': 619,
#  'ぷ': 620,
#  'へ': 621,
#  'べ': 622,
#  'ぺ': 623,
#  'ほ': 624,
#  'ぼ': 625,
#  'ぽ': 626,
#  'ま': 627,
#  'み': 628,
#  'む': 629,
#  'め': 630,
#  'も': 631,
#  'ゃ': 632,
#  'や': 633,
#  'ゅ': 634,
#  'ゆ': 635,
#  'ょ': 636,
#  'よ': 637,
#  'ら': 638,
#  'り': 639,
#  'る': 640,
#  'れ': 641,
#  'ろ': 642,
#  'ゎ': 643,
#  'わ': 644,
#  'ゐ': 645,
#  'ゑ': 646,
#  'を': 647,
#  'ん': 648,
#  'ゔ': 649,
#  'ァ': 650,
#  'ア': 651,
#  'ィ': 652,
#  'イ': 653,
#  'ゥ': 654,
#  'ウ': 655,
#  'ェ': 656,
#  'エ': 657,
#  'ォ': 658,
#  'オ': 659,
#  'カ': 660,
#  'ガ': 661,
#  'キ': 662,
#  'ギ': 663,
#  'ク': 664,
#  'グ': 665,
#  'ケ': 666,
#  'ゲ': 667,
#  'コ': 668,
#  'ゴ': 669,
#  'サ': 670,
#  'ザ': 671,
#  'シ': 672,
#  'ジ': 673,
#  'ス': 674,
#  'ズ': 675,
#  'セ': 676,
#  'ゼ': 677,
#  'ソ': 678,
#  'ゾ': 679,
#  'タ': 680,
#  'ダ': 681,
#  'チ': 682,
#  'ヂ': 683,
#  'ッ': 684,
#  'ツ': 685,
#  'ヅ': 686,
#  'テ': 687,
#  'デ': 688,
#  'ト': 689,
#  'ド': 690,
#  'ナ': 691,
#  'ニ': 692,
#  'ヌ': 693,
#  'ネ': 694,
#  'ノ': 695,
#  'ハ': 696,
#  'バ': 697,
#  'パ': 698,
#  'ヒ': 699,
#  'ビ': 700,
#  'ピ': 701,
#  'フ': 702,
#  'ブ': 703,
#  'プ': 704,
#  'ヘ': 705,
#  'ベ': 706,
#  'ペ': 707,
#  'ホ': 708,
#  'ボ': 709,
#  'ポ': 710,
#  'マ': 711,
#  'ミ': 712,
#  'ム': 713,
#  'メ': 714,
#  'モ': 715,
#  'ャ': 716,
#  'ヤ': 717,
#  'ュ': 718,
#  'ユ': 719,
#  'ョ': 720,
#  'ヨ': 721,
#  'ラ': 722,
#  'リ': 723,
#  'ル': 724,
#  'レ': 725,
#  'ロ': 726,
#  'ヮ': 727,
#  'ワ': 728,
#  'ヰ': 729,
#  'ヱ': 730,
#  'ヲ': 731,
#  'ン': 732,
#  'ヴ': 733,
#  'ヵ': 734,
#  'ヶ': 735,
#  'ヷ': 736,
#  'ヸ': 737,
#  'ヹ': 738,
#  'ヺ': 739,
#  'ー': 740,
#  'ヽ': 741,
#  'ヾ': 742,
#  '一': 743,
#  '丁': 744,
#  '丂': 745,
#  '七': 746,
#  '丄': 747,
#  '丅': 748,
#  '丆': 749,
#  '万': 750,
#  '丈': 751,
#  '三': 752,
#  '上': 753,
#  '下': 754,
#  '丌': 755,
#  '不': 756,
#  '与': 757,
#  '丏': 758,
#  '丐': 759,
#  '丑': 760,
#  '丒': 761,
#  '专': 762,
#  '且': 763,
#  '丕': 764,
#  '世': 765,
#  '丗': 766,
#  '丘': 767,
#  '丙': 768,
#  '业': 769,
#  '丛': 770,
#  '东': 771,
#  '丝': 772,
#  '丞': 773,
#  '丟': 774,
#  '丠': 775,
#  '両': 776,
#  '丢': 777,
#  '两': 778,
#  '严': 779,
#  '並': 780,
#  '丧': 781,
#  '丨': 782,
#  '丩': 783,
#  '个': 784,
#  '丫': 785,
#  '丬': 786,
#  '中': 787,
#  '丮': 788,
#  '丯': 789,
#  '丰': 790,
#  '丱': 791,
#  '串': 792,
#  '临': 793,
#  '丵': 794,
#  '丶': 795,
#  '丷': 796,
#  '丸': 797,
#  '丹': 798,
#  '为': 799,
#  '主': 800,
#  '丼': 801,
#  '丽': 802,
#  '举': 803,
#  '丿': 804,
#  '乀': 805,
#  '乁': 806,
#  '乂': 807,
#  '乃': 808,
#  '乄': 809,
#  '久': 810,
#  '乆': 811,
#  '乇': 812,
#  '么': 813,
#  '义': 814,
#  '乊': 815,
#  '之': 816,
#  '乌': 817,
#  '乍': 818,
#  '乎': 819,
#  '乏': 820,
#  '乐': 821,
#  '乑': 822,
#  '乒': 823,
#  '乓': 824,
#  '乔': 825,
#  '乕': 826,
#  '乖': 827,
#  '乗': 828,
#  '乘': 829,
#  '乙': 830,
#  '乚': 831,
#  '乛': 832,
#  '乜': 833,
#  '九': 834,
#  '乞': 835,
#  '也': 836,
#  '习': 837,
#  '乡': 838,
#  '乢': 839,
#  '乣': 840,
#  '乤': 841,
#  '乥': 842,
#  '书': 843,
#  '乧': 844,
#  '乨': 845,
#  '乩': 846,
#  '乪': 847,
#  '乫': 848,
#  '乬': 849,
#  '乭': 850,
#  '乮': 851,
#  '买': 852,
#  '乱': 853,
#  '乲': 854,
#  '乳': 855,
#  '乴': 856,
#  '乶': 857,
#  '乷': 858,
#  '乸': 859,
#  '乹': 860,
#  '乺': 861,
#  '乻': 862,
#  '乼': 863,
#  '乽': 864,
#  '乾': 865,
#  '亀': 866,
#  '亁': 867,
#  '亂': 868,
#  '亄': 869,
#  '亅': 870,
#  '了': 871,
#  '亇': 872,
#  '予': 873,
#  '争': 874,
#  '亊': 875,
#  '事': 876,
#  '二': 877,
#  '亍': 878,
#  '于': 879,
#  '亏': 880,
#  '亐': 881,
#  '云': 882,
#  '互': 883,
#  '亓': 884,
#  '五': 885,
#  '井': 886,
#  '亖': 887,
#  '亘': 888,
#  '亙': 889,
#  '亚': 890,
#  '些': 891,
#  '亜': 892,
#  '亞': 893,
#  '亟': 894,
#  '亠': 895,
#  '亡': 896,
#  '亢': 897,
#  '亣': 898,
#  '交': 899,
#  '亥': 900,
#  '亦': 901,
#  '产': 902,
#  '亨': 903,
#  '亩': 904,
#  '亪': 905,
#  '享': 906,
#  '京': 907,
#  '亭': 908,
#  '亮': 909,
#  '亯': 910,
#  '亰': 911,
#  '亲': 912,
#  '亳': 913,
#  '亴': 914,
#  '亶': 915,
#  '亷': 916,
#  '亸': 917,
#  '亹': 918,
#  '人': 919,
#  '亻': 920,
#  '亼': 921,
#  '亽': 922,
#  '亾': 923,
#  '亿': 924,
#  '什': 925,
#  '仁': 926,
#  '仂': 927,
#  '仃': 928,
#  '仄': 929,
#  '仅': 930,
#  '仆': 931,
#  '仇': 932,
#  '仈': 933,
#  '仉': 934,
#  '今': 935,
#  '介': 936,
#  '仌': 937,
#  '仍': 938,
#  '从': 939,
#  '仏': 940,
#  '仐': 941,
#  '仑': 942,
#  '仒': 943,
#  '仓': 944,
#  '仔': 945,
#  '仕': 946,
#  '他': 947,
#  '仗': 948,
#  '付': 949,
#  '仙': 950,
#  '仚': 951,
#  '仛': 952,
#  '仜': 953,
#  '仝': 954,
#  '仞': 955,
#  '仟': 956,
#  '仠': 957,
#  '仡': 958,
#  '仢': 959,
#  '代': 960,
#  '令': 961,
#  '以': 962,
#  '仦': 963,
#  '仨': 964,
#  '仪': 965,
#  '仫': 966,
#  '们': 967,
#  '仭': 968,
#  '仮': 969,
#  '仰': 970,
#  '仲': 971,
#  '仳': 972,
#  '仴': 973,
#  '仵': 974,
#  '件': 975,
#  '价': 976,
#  '仸': 977,
#  '仺': 978,
#  '任': 979,
#  '仼': 980,
#  '份': 981,
#  '仾': 982,
#  '仿': 983,
#  '伀': 984,
#  '企': 985,
#  '伂': 986,
#  '伃': 987,
#  '伄': 988,
#  '伅': 989,
#  '伆': 990,
#  '伈': 991,
#  '伉': 992,
#  '伊': 993,
#  '伋': 994,
#  '伌': 995,
#  '伍': 996,
#  '伎': 997,
#  '伏': 998,
#  '伐': 999,
#  ...}

# %%
[idx for idx, tkn in idx2tkn.items() if "/d" in tkn]
# Out:
# [8]
